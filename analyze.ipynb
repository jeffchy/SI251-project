32956123, 0.3290147, 0.32960114, 0.3294225, 0.32902944, 0.32937732, 0.329186, 0.3292281, 0.32920292, 0.3290086, 0.32919505, 0.32901114, 0.32900152, 0.3291339, 0.3289588, 0.3290136, 0.3290208, 0.32897824, 0.32903084, 0.32891765, 0.32895416, 0.32898486, 0.32890788, 0.3289502, 0.32893407, 0.32892188, 0.32894146, 0.3289059, 0.3289336, 0.3289167, 0.32889003, 0.32892078, 0.32890487, 0.32890093, 0.3289031, 0.32889476, 0.32891002, 0.32889628, 0.32889107, 0.3289018, 0.32889068, 0.32889307, 0.32889307, 0.32889012]
RLR_LBFGS = [0.59462243, 0.41074276, 0.98958784, 0.98979104, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917, 0.99999917]
RLR_PPO_08 = np.array([-0.59462243, -0.5625011, -0.46549878, -0.49774104, -0.51421285, -0.32929218, -0.4378835, -0.537851, -0.5490205, -0.44115484, -0.43965617, -0.4732757, -0.5268475, -0.38914308, -0.46569484, -0.49277386, -0.40393978, -0.49586418, -0.47309148, -0.34929803, -0.45146266, -0.45827252, -0.4189144, -0.48320675, -0.4606513, -0.50567514, -0.5278326, -0.61640364, -0.50154287, -0.54381716, -0.5357581, -0.4000154, -0.44619095, -0.42213207, -0.5283265, -0.44809636, -0.48468262, -0.48022214, -0.48818305, -0.4251303, -0.5142303, -0.43017942, -0.49009925, -0.49539003, -0.45473862, -0.4507266, -0.54050183, -0.553998, -0.5289785, -0.43814987, -0.5726596, -0.54700094, -0.5114709, -0.5304221, -0.53389376, -0.39649925, -0.5095772, -0.47603166, -0.39787692, -0.48512754, -0.4757083, -0.5155808, -0.47666368, -0.5460727, -0.46603283, -0.3892725, -0.5473452, -0.37683252, -0.52466226, -0.57088715, -0.6151631, -0.4333632, -0.47620133, -0.58469385, -0.41543946, -0.50225616, -0.5153406, -0.49317086, -0.4520144, -0.3734726, -0.5501324, -0.42687988, -0.5595162, -0.48884973, -0.43568665, -0.44387078, -0.45965332, -0.40891758, -0.45783842, -0.54125774, -0.47881794, -0.44873318, -0.44556308, -0.49313515, -0.43870997, -0.37584582, -0.50874937, -0.4199984, -0.55730265, -0.4544631])*-1

# %%
data3 = np.array([RLR_PPO_08, RLR_SGD, RLR_Momentum, RLR_LBFGS]).T
df3 = pd.DataFrame(data3, columns=["PPO", "GD", "Momentum", "L-BFGS"])
ax = sns.lineplot(data=df3)
ax.set(xlim=(-0, 20))
# Out:
# [(0, 20)]

# %%
with open('data/NNCE', 'r') as f:
    logs = f.read()
    logs = logs.split('\n')

# %%
Episodes = []
HasDoneRates = []
AvgRewards = []
AvgInitRewards = []

for l in logs:
    l = l.split()
    Episode = int(l[4])
    HasDoneRate = float(l[10])
    AvgReward = float(l[17].replace(',',''))*-1
    AvgInitReward = float(l[25].replace(',',''))*-1
    Episodes.append(Episode)
    HasDoneRates.append(HasDoneRate)
    AvgRewards.append(AvgReward)
    AvgInitRewards.append(AvgInitReward)

# %%
data4 = np.array([Episodes, HasDoneRates, AvgRewards, AvgInitRewards]).T

# %%
df4 = pd.DataFrame(data4, columns=["Episodes", "HasDoneRates", "AvgRewards", "AvgInitRewards"])

# %%
ax = sns.lineplot(data=df4, x='Episodes', y='HasDoneRates')

# %%
ax = sns.lineplot(data=df4, x='Episodes', y='AvgRewards', )
ax = sns.lineplot(data=df4, x='Episodes', y='AvgInitRewards', )

# %%
ax = sns.lineplot(data=df4, x='Episodes', y='AvgRewards', )
ax = sns.lineplot(data=df4, x='Episodes', y='AvgInitRewards', )
ax.set(ylim=(0, 3))
# Out:
# [(0, 3)]
